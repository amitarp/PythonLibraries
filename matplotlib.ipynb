# %% [markdown]
# ### Importing the Libraries

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import random
import datetime

#reloads the notebook whenever chnages are made
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Functional Plot

# %%
#creates 10 floats from 0 to 5
x1=np.linspace(0,5,10)
y1=x1**2
plt.plot(x1,y1)
plt.title('Squared Chart')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %% [markdown]
# ## Print Multiple Plots

# %%
plt.subplot(1,2,1)
plt.plot(x1,y1,'r')
plt.subplot(1,2,2)
plt.plot(y1,x1,'b')

# %% [markdown]
# ## Using Figure object

# %%
fig1=plt.figure(figsize=(5,4),dpi=100)
axes1=fig1.add_axes([0.1,0.1,0.9,0.9])#left,bottom,width,height
axes1.set_xlabel('X axis')
axes1.set_ylabel('Y axis')
axes1.set_title('Sqaured Chart')
axes1.plot(x1,y1,label='x/x')

# %%
fig1=plt.figure(figsize=(5,4),dpi=100)
axes1=fig1.add_axes([0.1,0.1,0.9,0.9])#left,bottom,width,height
axes1.set_xlabel('X axis')
axes1.set_ylabel('Y axis')
axes1.set_title('Sqaured Chart')
axes1.plot(x1,y1,label='x/x2')
axes1.plot(y1,x1,label='x2/x')
axes1.legend(loc=0)

#plotting another graph of smaller size
axes2=fig1.add_axes([0.45,0.45,0.4,0.3])#left,bottom,width,height
axes2.set_xlabel('X axis')
axes2.set_ylabel('Y axis')
axes2.set_title('Sqaured Chart')
axes2.plot(x1,y1,label='x/x2')
axes2.plot(y1,x1,label='x2/x')

axes2.text(0,35,'Inner Message')
axes1.text(0,30,'Outer Message')
# Out:
# Text(0, 30, 'Outer Message')

# %% [markdown]
# ### Different values of loc:
# ##### loc==1: Upper left
# ##### loc==2: Upper Right
# ##### loc==3: Lower Left
# ##### loc==4: Lower right

# %% [markdown]
# ## SubPlots

# %%
fig2,axes2=plt.subplots(figsize=(8,4),nrows=1,ncols=3)
#used when plots are overlapping
plt.tight_layout()
axes2[1].set_title('Plot 2')
axes2[1].set_xlabel('X axis')
axes2[1].set_ylabel('Y axis')
axes2[1].plot(x1,y1)

# %% [markdown]
# ## Appearance Options

# %%
# Default colors (b: blue, g: green, r: red, c: cyan, m: magenta,
# y: yellow, k: black, w: white)
# color="0.75" creates a 75% gray
# You can use hexcodes color="#eeefff"
# You can use color names found next like this color="burlywood"
# https://en.wikipedia.org/wiki/Web_colors


# alpha defines the percentage of opacity

# The default line width is 1, so to double it put in 2 and so forth

# There are many line styles 
# matplotlib.org/3.1.0/gallery/lines_bars_and_markers/linestyles.html


# Markers can mark your provided points on the graph
# https://matplotlib.org/3.3.0/api/markers_api.html
# You can change the markersize as well

# markerfacecolor changes the marker fill color
# markeredgecolor changes the marker stroke color
# markeredgewidth changes the markers stroke size

# %%
fig3=plt.figure(figsize=(6,4))
axes3=fig3.add_axes([0,0,1,1])
axes3.plot(x1,y1,color='navy',alpha=0.75,lw=2,ls='-.',marker='o',markersize=7,markerfacecolor='y',markeredgewidth=4,markeredgecolor='y')

#5pts 1 pt dashes separated by 2pt space
axes3.grid(True,color='0.6',dashes=(5,2,1,2))

# Set grid background color
axes3.set_facecolor('#FAEBD7')

# %% [markdown]
# ## Saving visualizations to a file

# %%
# You can save your plots to numerous file types : png, pdf, ps, eps, svg, pgf
fig3.savefig('3rdplot.png')

# %% [markdown]
# ## Working with Pandas Dataframe

# %%
data=pd.read_csv('icecreamsales.csv')
#sorting the data wrt temperature
data=data.sort_values(by='Temperature')

# %%
data
# Out:
#     Temperature  Sales
# 0            37    292
# 1            40    228
# 11           42    320
# 2            49    324
# 10           53    324
# 3            61    376
# 9            64    412
# 4            72    440
# 8            75    496
# 5            79    496
# 7            81    556
# 6            83    536

# %%
#converting into numpy array
npArray=data.values
x2=npArray[:,0]
y2=npArray[:,1]

fig4=plt.figure(figsize=(6,4))
axes4=fig4.add_axes([0,0,1,1])
axes4.set_xlabel('X axis-Temperature')
axes4.set_ylabel('Y axis-Sales')
axes4.set_title('Sales Vs Temperature Chart')
axes4.plot(x2,y2)


# Add Annotations by supplying the x & y to point at and the position of the text
# based off of lower left had corner being 0,0
axes4.annotate('Good Month',xy=(83,536),xytext=(60,520),arrowprops=dict(facecolor='black',shrink=0.05))

plt.bar(x2,y2)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# ## Tex Markup

# %%
# You can use a subset of TeX markup by placing text between $
# matplotlib.org/tutorials/text/mathtext.html

# All listed plus kappa, iota, zeta, nu, rho, eta, xi, omicron, gamma, tau, phi, 
# chi, psi, delta (Capitalize the first letter for uppercase)

# %%
fig5 = plt.figure(figsize=(5,4),dpi=100)
axes5 = fig5.add_axes([0.1,0.1,0.9,0.9])

axes5.text(0,23,r'$\alpha\beta\omega\mu\sigma\theta\lambda\pi\epsilon\gamma\delta$')
axes5.text(0,18,r'$\delta_i\gamma^{ij}\sum_{i=0}^\infty x_i\frac{3}{4}$')
axes5.text(0,13,r'$\frac{8-\frac{3}{4}}{8}\sqrt{3}\sin(\pi)\sqrt[3]{4}\acute a\div$')
axes5.text(0,8,r'$\bar a\hat a\tilde a\vec a\overline {a}\lim_{x \to 2}f(x)=5$')
axes5.text(0,3,r'$\geq\leq\ne$')

axes5.plot(x1,y1)

# %% [markdown]
# ## Histogram

# %%
#generates 5000 numbers randomly from 1 to 6
arr1 = np.random.randint(1,7,5000)
arr2 = np.random.randint(1,7,5000)
arr3 = arr1 + arr2

# %%
arr1
# Out:
# array([1, 6, 4, ..., 4, 3, 6])

# %%
arr2
# Out:
# array([6, 4, 2, ..., 1, 3, 3])

# %%
arr3
# Out:
# array([ 7, 10,  6, ...,  5,  6,  9])

# %%
# Bins reprsent the number of options available 2 thru 12 = 11
# Density returns the frequency of each bin
# Range gets tuple with bin range interested in
# cumulative=True use a cumulative distribution
# histtype='step' genrates a line plot
# orientation='horizontal' 
# color='orange' change bar color

# %%
plt.hist(arr3,bins=11,density=True,stacked=True)
# Out:
# (array([0.02794, 0.05808, 0.0869 , 0.11572, 0.15994, 0.19272, 0.14344,
#         0.1353 , 0.08844, 0.06182, 0.0297 ]),
#  array([ 2.        ,  2.90909091,  3.81818182,  4.72727273,  5.63636364,
#          6.54545455,  7.45454545,  8.36363636,  9.27272727, 10.18181818,
#         11.09090909, 12.        ]),
#  <BarContainer object of 11 artists>)

# %% [markdown]
# ## Bar Charts

# %%
# Analyze where France gets its electricity from
x = ['Nuclear', 'Hydro', 'Coal', 'Gas', 'Solar', 'Wind', 'Other']
per1 = [71, 10, 3, 7, 2, 4, 3]
# Chart variance in usage
variance = [8, 3, 1, 3, 1, 2, 1]

# %%
# barh makes horizontal chart
# Also yerr, change error color with ecolor
plt.bar(x,per1,color='purple',yerr=variance)
# Out:
# <BarContainer object of 7 artists>

# %%
# Show percentages of males & females in engineering
mEng = (76, 85, 86, 88, 93)
fEng = (24, 15, 14, 12, 7)

# %%
spc=np.arange(5)
plt.bar(spc,mEng,width=0.45,edgecolor='k',label='Male')
plt.bar(spc+0.45,fEng,width=0.45,edgecolor='k',label='Female')
# Define x tick names and place in middle of bars
plt.xticks(spc + 0.45 / 2, ('Aero', 'Chem', 'Civil', 'Elec', 'Mech'))
# Out:
# ([<matplotlib.axis.XTick at 0x1fda2517cd0>,
# ...
#  [Text(0.225, 0, 'Aero'),
#   Text(1.225, 0, 'Chem'),
#   Text(2.225, 0, 'Civil'),
#   Text(3.225, 0, 'Elec'),
#   Text(4.225, 0, 'Mech')])

# %%
tType = ['Kind', 'Elem', 'Sec', 'Spec']
mTeach = np.array([2, 20, 44, 14])
fTeach = np.array([98, 80, 56, 86])

# %%
ind=[x for x,_ in enumerate(tType)]
plt.bar(ind,mTeach,width=0.45,label='Male',bottom=fTeach)
plt.bar(ind,fTeach,width=0.45,label='Female')
plt.legend(loc='lower right')

# %% [markdown]
# ## Pie Charts

# %%
fig6 = plt.figure(figsize=(8,5),dpi=100)
axes6 = fig6.add_axes([0.1,0.1,0.9,0.9])

# Create a pie chart of the number of Pokemon by type
types = ['Water', 'Normal', 'Flying', 'Grass', 'Psychic', 'Bug', 'Fire', 'Poison',
'Ground', 'Rock', 'Fighting', 'Dark', 'Steel', 'Electric', 'Dragon', 'Fairy',
'Ghost', 'Ice']
poke_num = [133, 109, 101, 98, 85, 77, 68, 66, 65, 60, 57, 54, 53, 51, 50, 50, 46, 40]

#generating random colors
color=[]
for i in range(18):
    rgb=(random.uniform(0,1),random.uniform(0,1),random.uniform(0,1))
    color.append(rgb)
    
explode=[0]*18
explode[0]=0.2


# Provide values, what to explode and by how much, labels, colors, pct for values,
# whether to shadow, amount to rotate pie, pie text color
wedges,text,autotext=plt.pie(poke_num,explode=explode,labels=types,colors=color,autopct='%1.0f%%',shadow=True,startangle=140,textprops=dict(color='w'))

# Create legend to right and move off pie with 1-1.5 axes point width
plt.legend(wedges, types, loc='right', bbox_to_anchor=(1, 0, 0.5, 1))
